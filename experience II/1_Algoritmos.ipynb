# %% [markdown]
# <h1 style="border:3px solid DodgerBlue; text-align:center;color:gray">Algorithms</h1>

# %% [markdown]
# <h3 style="text-align:right; color:blue"><b>Hecho por:</b> Miller Alexander Quiroga Campos</h3>
#
#
# <div style="text-align:right; color:gray">
#     Ing. Electrónico <br>
#     Matemático<br>
#     Docente de Ingeniería
#     <hr>
# </div>

# %% [markdown]
# <h3 style="text-align:center;color:gray">Python</h3>

# %% [markdown]
# <p>Python es un lenguaje de programación de propósito general, versátil y poderoso. Es un excelente primer lenguaje porque es conciso y fácil de leer. Lo que sea que quieras hacer, Python puede hacerlo. Desde desarrollo web hasta aprendizaje automático y ciencia de datos, Python es el lenguaje para usted.</p>
# <p>
# Por qué es un lenguaje que encanta a muchos programadores y desarrolladores: <br>
# <ul>
# <li>Idioma ingles</li>
# <li>Gran comunidad de programación</li>
# <li>Excelente documentación en línea</li>
# <li>Bibliotecas y paquetes interminables</li>
# <li>Popularidad mundial</li>
# <li>Potente y flexible</li>
# <li>Propositos Generales</li>
# </ul>
# <p/>

# %% [markdown]
# <h3 style="background-color:rgba(255, 99, 71, 0.3);text-align:center">Prácticas en Python</h3>

# %% [markdown]
# <p>
# El mejor algoritmo no es el más corto, si no el que sea más sencillo de leer. Cerca del 80% del tiempo y trabajo de un programador se centra en leer código. En el tiempo restante se escriben algoritmos.
# </p>
# <p>
#     Para facilitar la lectura, es importante documentar el código con comentarios.
# </p>
# <p>
# En Python, los comentarios de frases inician con ‘#’ y los comentarios de más de una frase se emplean ‘”””’. Por ejemplo:
# </p>

# %% [markdown]
# >>
# ```
# # Ejemplo de un comentario de línea.
#
# """
# Comentario de muchas
# líneas
# .
# .
# .
# """
# ```

# %%
# Inicio de código

"""
En esta sesión,
Es un ejemplo de un comentario
multilínea, que puede usarse para un parrafo de una, dos o más lineas.
Estas líneas en comentario # o en """" .... """", no son ejecutadas por el programa, solamente leidas.
FIN.
"""

# %% [markdown]
# <h3 style="text-align:center;color:gray">Tipo de Variables</h3>

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# <h3 style="text-align:center;color:gray">Operadores</h3>

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <h1 style="background-color:SlateBlue;text-align:center; color:white">1.   Variables</h1>

# %% [markdown]
# <p>
#     Una variable es el nombre con el que se identifica información de interés. En Python, una variable se compone de lo siguiente:
# </p>
#
# <p style="text-align:center">
#     $nombre_{variable} = contenido$
# </p>
#
# <p>
# Python es un lenguaje dinámico, por lo que el contenido de una variable, además de su valor, puede cambiar de naturaleza.
# </p>

# %% [markdown]
# <h3 style="background-color:rgba(255, 99, 71, 0.3);text-align:center">Naturaleza de las variables</h3>

# %% [markdown]
# <ol>
# <li>Numérico</li>
#     <ul>
#         <li>Entero - Integer - <b>int</b></li>
#         <li>Decimal - Float - <b>float</b></li></ul>
# <li>Cadena de texto - String - <b>str</b></li>
# <li>Booleano - Bool - <b>bool</b></li>
# <li>listas - <b>list</b></li>
# <li>tuplas - tuple - <b>tuple</b></li>
# <li>diccionarios - <b>dict</b></li>
# </ol>
# <br>
# Con la función <b>type()</b> puedo saber la naturaleza de la variable
# <p/>
# <br>
# <br>
#
# | Naturaleza | Ejemplo  |
# |----------|---|
# | Numérico | `x = 5`  ó `y = 3.14159265359`|
# | Texto  |  `text = 'Esta es una frase'` |
# | Lista    | `lista = [0,1,2,"texto"]`  |
# | Tupla | `tupla = (0,1,2,"texto")` |
# | Diccionario | `dic = {"num":5, "text": "hola"}`  |

# %% [markdown]
# <h3 style="text-align:center;color:gray">1.1. Variables Numéricas</h3>

# %%
#    Declarar una variable numérica es igual que en el álgebra...
x = 50.3
print(x)
# Out:
# 50.3

# %%
x = 5
w = 10
z = 20
print("La variable x es de valor: " + str(x))
print("La variable w es de valor:", w)
print(f'La variable z es de valor: {z}')

#Podemos ser más específicos a la hora de imprimir información
# Out:
# La variable x es de valor: 5
# La variable w es de valor: 10
# La variable z es de valor: 20

# %% [markdown]
# También se pueden hacer operaciones matemáticas, pero _cuidado_: es importante escribir bien las ecuaciones.
#
# Si se quisiera resolver:
#
# $$
# \begin{equation}
#   y = \frac{x}{w \, z}
# \end{equation}
# $$
#
# Se debe escribir el algoritmo así:

# %% [markdown]
# Porque si se escribe y ejecuta así:

# %% [markdown]
# Se estaría realmente resolviendo:
#
# $$
# \begin{equation}
#   y = \frac{x}{w} z
# \end{equation}
# $$
#
# <h1><strong>Ejercicio:</strong></h1>
#
# Resuelve la siguiente ecuación:
#
# $$
# \begin{equation}
#   y = \frac{m \, n}{m ^{2}} \frac{n +1}{ \left(n^{-2} m \right) ^{3}}
# \end{equation}
# $$
#
#
# Dónde:
#
# * $n = 2$
# * $m = 10$

# %%
n = 2
m = 10
y=((m*n)/(m ** 2)) * ((n+1)/((n**-2)*m)**3)
print(y)
# Out:
# 0.038400000000000004

# %%
n = 2
m = 10
y = ((m * n) / (m ** 2)) * ((n+1) / (n ** (-2) * m ) ** 3)
print(y)
# Out:
# 0.038400000000000004

# %% [markdown]
# <h3 style="text-align:center;color:gray">1.2. Variables de texto</h3>

# %%
t = "Esta es una oración"   #De igual manera que la variable numérica.

# %%
t
# Out:
# 'Esta es una oración'

# %%
y
# Out:
# 0.038400000000000004

# %%
print(t)
# Out:
# Esta es una oración

# %%
print("Hola chichos, por favor utilizemos Google Colab para empezar la clase")
# Out:
# Hola chichos, por favor utilizemos Google Colab para empezar la clase

# %%
print(10-35)
# Out:
# -25

# %%
print('10-35')
# Out:
# 10-35

# %%
# t  es un string (Una cadena de texto, caracteres)
# t2 es un string (Una cadena de texto, caracteres)

# %%
#Es posible adicionar texto
t = "Esta es una oración" 
t2 = ", ¿o no?"
t2
# Out:
# ', ¿o no?'

# %%
frase_completa = t+t2
print(frase_completa)
# Out:
# Esta es una oración, ¿o no?

# %%
#Podemos también acceder a las letras en un texto
print(frase_completa[5])
# Out:
# e

# %%
#Podemos también acceder a las letras en un texto
print(frase_completa[-1])
# Out:
# ?

# %%
#Podemos también acceder a las letras en un texto
print(frase_completa[-10])
# Out:
# ó

# %%
#Y a fragmentos de una oración
print(frase_completa[0:8])
# Out:
# Esta es

# %%
ALFA = "Romeo esta visitando a Julienta"
print(ALFA)
# Out:
# Romeo esta visitando a Julienta

# %%
bETHA = 0.57

# %%
gamma = ALFA + str(bETHA)

# %%
print(gamma)
# Out:
# Romeo esta visitando a Julienta0.57

# %%
a = "2"
print(a)

# %%
b = 2
print(b)

# %%
c = a == b

# %%
print(c)

# %% [markdown]
# # Saltos de linea en una variable de texto o un print

# %% [markdown]
# con 3 comillas podemos realizar el salto de linea en una variable textual o en un print.
#
# Ejemplo:

# %%
var_1 = """Hola Apreciados estudiantes,
este es un ejemplo de una variable -
con 3 saltos """

print(var_1)

# %%
print("""Este es otro 
Ejemplo de un salto de 
3 lineas o más, desde un print
ok

Pueden hacer ejemplos """)

# %% [markdown]
# ## Entradas - input()
#
# *    Las entradas son peticiones a usuarios, cuando en las instrucciones del código no hay alguna opción para ingresar el valor o cóntenido.
#
# Ejemplo:
#
# -    Nombre
# - Dirección
# - Peso
# - Estatura
# - Correo
# - y otros

# %%
input("Ingresa tu nombre: ")
# Out:
# Ingresa tu nombre: MILLER QUIROGA
# 'MILLER QUIROGA'

# %%
edad = input('Ingresa tu edad: ')
# Out:
# Ingresa tu edad: 30

# %%
type(edad)
# Out:
# str

# %%
año = int(input('Ingresa el año de nacimiento: '))
print(año)
print(type(año))
print('Tienes la edad:', 2022 - año)
# Out:
# Ingresa el año de nacimiento: 1982
# 1982
# <class 'int'>
# Tienes la edad: 40

# %%
name = input("""Hola, Bienvenido al programa de horario de tus asignaturas cafam, 
por favor ....
Ingrese su Nombre: 
""")
# Out:
# Hola, Bienvenido al programa de horario de tus asignaturas cafam,
# por favor ....
# Ingrese su Nombre:
# Miller Alexander Quiroga Campos

# %%
name
# Out:
# 'Miller Alexander Quiroga Campos'

# %%
lunes = input("Ingrese el primer día de la semana")
martes = input("Ingrese el segundo día de la semana")
miercoles = input("Ingrese el tercer día de la semana")
jueves = input("Ingrese el cuarto día de la semana")
viernes = input("Ingrese el quinto día de la semana")
